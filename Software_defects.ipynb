# %%
# %matplotlib inline
import pandas as pd

# %%
file = pd.read_excel('Hack_A_Thon_DataSet_Rev1.xls',index = False)
file.describe()
# Out:
#        no of artifacts  artifact trend  perf. as reviewer  \
# count     14999.000000    14999.000000       14999.000000
# mean          3.576705        0.391759          12.978232
# std           3.942779        4.801376          44.457702
# min           1.000000      -49.000000           0.000000
# 25%           1.000000       -1.000000           0.000000
# 50%           2.000000        0.000000           0.000000
# 75%           4.000000        2.000000           8.000000
# max          56.000000       50.000000        1990.000000
#
#        avg. quality of reviewer   author's cummulated quality  duration(days)  \
# count               14999.000000                 14999.000000    14999.000000
# mean                 1348.670239                     0.018914       17.483744
# std                   461.519558                     0.122708       46.619641
# min                     1.000000                     0.000000       -1.000000
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# no of artifacts                14999 non-null int64
# artifact trend                 14999 non-null int64
# perf. as reviewer              14999 non-null float64
# avg. quality of reviewer       14999 non-null float64
# author's cummulated quality    14999 non-null float64
# duration(days)                 14999 non-null float64
# complexity                     14999 non-null float64
# consistency in load            14999 non-null float64
# consistency in quality         14999 non-null float64
# total defects count            14999 non-null int64
# dtypes: float64(7), int64(3)
# memory usage: 1.1 MB

# %%
file['previous_month_artifact'] = file['no of artifacts']-file['artifact trend']
file['duration']
data = file.drop('artifact trend', axis = 1)

target = file['total defects count']
data.head(100)
# Out:
#     no of artifacts  perf. as reviewer  avg. quality of reviewer   \
# 0                 3                0.0                1586.000000
# 1                 2                0.0                 963.500000
# 2                 1                0.0                1384.000000
# 3                 1                0.0                1384.000000
# 4                 2                0.0                1479.000000
# 5                 1                0.0                1241.000000
# 6                 2                0.0                1479.000000
# 7                 3                0.0                1357.666667
# 8                 1                0.0                 201.000000
# 9                 1                0.0                1479.000000
# 10                5                0.0                1541.400000
# 11                2                9.5                1628.000000
# 12                2                0.0                1118.000000
# ...

# %%
pd.plotting.scatter_matrix(file,figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E162A91F60>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1676F4F98>]], dtype=object)

# %% [raw]
# file.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
file.corr()
# Out:
#                              no of artifacts  artifact trend  \
# no of artifacts                     1.000000        0.604667
# artifact trend                      0.604667        1.000000
# perf. as reviewer                   0.042698        0.047153
# avg. quality of reviewer           -0.000052       -0.011391
# author's cummulated quality         0.041013       -0.008021
# duration(days)                     -0.039065        0.020241
# complexity                          0.878752        0.513560
# consistency in load                 0.129539        0.281515
# consistency in quality              0.236218        0.093221
# total defects count                 0.160173        0.164937
# previous_month_artifact             0.262315       -0.609974
#
#                              perf. as reviewer  avg. quality of reviewer   \
# no of artifacts                       0.042698                  -0.000052
# artifact trend                        0.047153                  -0.011391
# ...

# %%
sns.boxplot(file['complexity'])

# %%
sns.boxplot(file['duration(days)'])

# %%
sns.boxplot(file['no of artifacts'])

# %%
sns.boxplot(file['perf. as reviewer'])

# %%
sns.boxplot(file['avg. quality of reviewer '])

# %%
sns.boxplot(file["author's cummulated quality"])

# %%
sns.boxplot(file["consistency in load"])

# %%
sns.boxplot(file["consistency in quality"])

# %%
fig = plt.figure(size = (10,10))
fig.subplot(1,2,2)
sns.distplot(file['complexity'])

# %%
sns.distplot(file['avg. quality of reviewer '])
